# %% [markdown]
# # [Gender]  [Sexual Orientation]  [Race]  [Compensation]
#
# ### Gender: Woman, Man, Transgender, Other
#
# ### Sexual Orientation: Heterosexual, Homosexual, Bisexual, Other
#
# ### Race: American Indian or Alaska Native, Asian, Black or African American, Native Hawaiian or Other Pacific Islander, and White

# %% [markdown]
# Non-Hispanic white  60.4%
# Hispanic and Latino (of any race)  18.3%
# Black or African American  13.4%
# Asian  5.9%
# Native Americans and Alaska Natives  1.3%
# Native Hawaiians and Other Pacific Islanders  0.2%
# Two or more races  2.7%

# %%
# import useful libraries
import numpy as np
from numpy.linalg import cholesky
import matplotlib.pyplot as plt

# %%
#gender

woman_num = 500
woman_mean = 806 #weekly salary

mam_num = 500
man_mean = 1004

#transgender_num = 1000
#trans_mean = 

#other_num = 1000
#other_mean =

# %%
def generate_gaussian(mean_value, sigma, number, seed=0):
    np.random.seed(seed)
    s = np.random.normal(mean_value, sigma, number )
    return s

# %%
s = generate_gaussian(1004, 300, 500, seed=0)

# %%
s
# Out:
# array([1533.21570379, 1124.04716251, 1297.62139523, 1676.26795976,
#        1564.26739704,  710.81663604, 1289.02652526,  958.59283751,
#         973.03434446, 1127.17955058, 1047.21307135, 1440.28205209,
#        1232.31131754, 1040.50250495, 1137.15896982, 1104.10229821,
#        1452.22372195,  942.45252087, 1097.9203105 ,  747.77127821,
#         238.10305525, 1200.08557863, 1263.33085966,  781.35049388,
#        1684.9263872 ,  567.69029762, 1017.72755519,  947.84484499,
#        1463.83376431, 1444.80763097, 1050.48422771, 1117.44875588,
#         737.66427571,  409.76105953,  899.6263552 , 1050.90469073,
#        1373.08720422, 1364.71395464,  887.80195478,  913.30917483,
#         689.43411048,  577.99461885,  492.11894281, 1589.23261857,
#         851.10434547,  872.57770952,  628.16139199, 1237.24710675,
#         519.83064573,  940.17791594,  735.36003164, 1120.07074936,
#         850.75845873,  649.81034476,  995.5453315 , 1132.49956116,
# ...

# %%
#sexual orientation 
hetero_num = 
hetero_mean = 

homo_num = 
homo_mean = 

bi_num = 
bi_mean = 

other_num = 
other_mean =

# %%
male_white = generate_gaussian(1273, 250, 391, seed=0)
male_black = generate_gaussian(957, 250, 37, seed=0)
male_asian = generate_gaussian(1408, 250, 46, seed=0)
male_latino = generate_gaussian(1002, 250, 47, seed=0)

female_white = generate_gaussian(932, 250, 404, seed=0)
female_black = generate_gaussian(812, 250, 58, seed=0)
female_asian = generate_gaussian(1143, 250, 39, seed=0)
female_latino = generate_gaussian(789, 250, 50, seed=0)

# %%
np.savetxt("male_white.csv", male_white)
np.savetxt("male_black.csv", male_black)
np.savetxt("male_asian.csv", male_asian)
np.savetxt("male_latino.csv", male_latino)

np.savetxt("female_white.csv", female_white)
np.savetxt("female_black.csv", female_black)
np.savetxt("female_asian.csv", female_asian)
np.savetxt("female_latino.csv", female_latino)

# %%
male_white_hete = generate_gaussian(1280.2, 250, 380, seed=0)
male_white_homo = generate_gaussian(1224.16, 250, 8, seed=0)

male_black_hete = generate_gaussian(972.7, 250, 34, seed=0)

male_asian_hete = generate_gaussian(1426.6, 250, 43, seed=0)

male_latino_hete = generate_gaussian(1015, 250, 44, seed=0)

female_white_hete = generate_gaussian(938.5, 250, 390, seed=0)
female_white_homo = generate_gaussian(750.8, 250, 10, seed=0)

female_black_hete = generate_gaussian(820.5, 250, 55, seed=0)

female_asian_hete = generate_gaussian(1160.86, 250, 36, seed=0)

female_latino_hete = generate_gaussian(798.6, 250, 47, seed=0)

# %%
np.savetxt("male_white_hete.csv", male_white_hete)
np.savetxt("male_white_homo.csv", male_white_homo)
np.savetxt("male_black_hete.csv", male_black_hete)
np.savetxt("male_asian_hete.csv", male_asian_hete)
np.savetxt("male_latino_hete.csv", male_latino_hete)

np.savetxt("female_white_hete.csv", female_white_hete)
np.savetxt("female_white_homo.csv", female_white_homo)
np.savetxt("female_black_hete.csv", female_black_hete)
np.savetxt("female_asian_hete.csv", female_asian_hete)
np.savetxt("female_latino_hete.csv", female_latino_hete)
